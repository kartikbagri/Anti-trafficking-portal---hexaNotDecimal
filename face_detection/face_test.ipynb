# %%
from deepface import DeepFace
import matplotlib.pyplot as plt
result = DeepFace.verify('v1_test.jpg', 'm_test.jpg', model_name = 'Facenet')
print(result)
plt.imshow(plt.imread('v1_test.jpg'))
# Out:
# {'verified': False, 'distance': 1.0547281644372501, 'threshold': 0.4, 'model': 'Facenet', 'detector_backend': 'opencv', 'similarity_metric': 'cosine'}
